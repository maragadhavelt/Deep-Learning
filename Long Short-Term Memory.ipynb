# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Create dummy time-series data
timesteps = 100
X = np.random.rand(1000, timesteps, 1)
y = np.sum(X, axis=1)

# Build model (correct way without warning)
model = keras.Sequential([
    keras.Input(shape=(timesteps, 1)),
    layers.LSTM(64),
    layers.Dense(1)
])

# Compile model
model.compile(optimizer='adam', loss='mse')

# Train model and store history
history = model.fit(X, y, epochs=5)

# Plot training loss
plt.figure()
plt.plot(history.history['loss'], marker='o')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 2288.5242
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 1735.3928
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1428.7607
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1236.8225
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1078.2883
